# %% [markdown]
# ### Libraries and function import

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# ### Data Split and Normalize

# %% [markdown]
# ### MODELS

# %% [markdown]
# ### Comparison bewtween models

# %% [markdown]
# ### Final Model
