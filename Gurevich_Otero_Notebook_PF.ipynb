# %% [markdown]
# ### Libraries and functions importation

# %%
import sys
sys.path.append("..")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import sklearn
import xgboost
import lightgbm
import catboost

# %% [markdown]
# ### EDA

# %% [markdown]
# **Preprocessing**

# %%
data = pd.read_csv('./data/pf_suvs.csv')

# %%
summary = pd.DataFrame({
    "dtype": data.dtypes,
    "nulos": data.isnull().sum(),
    "unicos": data.nunique()
})
summary
# Out:
#                            dtype  nulos  unicos
# Unnamed: 0                 int64      0   18254
# Marca                        str      0      47
# Modelo                       str      0     137
# Año                      float64      0      40
# Versión                      str      0    2072
# Color                        str    389      70
# Tipo de combustible          str      0       8
# Puertas                  float64      0       7
# Transmisión                  str     15       4
# Motor                        str     38     271
# Tipo de carrocería           str      0       1
# Con cámara de retroceso      str  13563       2
# Kilómetros                   str      0    2175
# Título                       str      0    2220
# Precio                   float64      0    2914
# Moneda                       str      0       2
# Descripción                  str      0   12142
# Tipo de vendedor             str      0       3

# %%
data.describe()
# Out:
#          Unnamed: 0            Año       Puertas  Con cámara de retroceso  \
# count  18254.000000   18254.000000  18254.000000             18254.000000
# mean    9126.500000    2042.796209     18.167306                 0.818834
# std     5269.620242    3217.260996    891.766121                 0.385166
# min        0.000000    1981.000000      2.000000                 0.000000
# 25%     4563.250000    2016.000000      5.000000                 1.000000
# 50%     9126.500000    2019.000000      5.000000                 1.000000
# 75%    13689.750000    2024.000000      5.000000                 1.000000
# max    18253.000000  436694.000000  60252.000000                 1.000000
#
#              Precio
# count  1.825400e+04
# mean   1.760162e+07
# std    1.720810e+07
# min    1.110000e+02
# 25%    3.190000e+04
# 50%    1.720000e+07
# 75%    2.995000e+07
# max    3.495000e+08

# %%
#Imprimir la cantidad UNICA de elementos por feature
for col in data.columns:
    print(c, data[col].nunique())
# Out:
# Unnamed: 0 18254
# Marca 47
# Modelo 137
# Año 40
# Versión 2072
# Color 70
# Tipo de combustible 8
# Puertas 7
# Transmisión 4
# Motor 271
# Tipo de carrocería 1
# Con cámara de retroceso 2
# Kilómetros 2175
# Título 2220
# Precio 2914
# Moneda 2
# Descripción 12142
# Tipo de vendedor 3

# %% [markdown]
# ideas para sol el prepro:
# LOs null :
# 1. Camara de retroceso  :   Moda * (marca + año)
# 2. pasar one hot , knn completar ocn KNN IMPUTER
# 3. motor : BORARR
# 4. color:  Moda * (marca + modelo)
#
#
# borrar la unnamed
# hacer col de 0km y usado
# pasaar las monedas todas a usd  y precio logico (ver tipo )y la saco
# limpiar SUV
# pasar a 5 puertaas PUERTAS

# %%
data["Puertas"].value_counts().sort_index()
# Out:
# Puertas
# 2.0           10
# 3.0          105
# 4.0          399
# 5.0        17731
# 6.0            3
# 7.0            2
# 60252.0        4
# Name: count, dtype: int64

# %% [markdown]
# vemos boxplot para outliers y distribucion

# %%
sns.histplot(data["Precio"], bins=50)
plt.show()
data["Precio"].describe()
# Out:
# count    1.825400e+04
# mean     1.760162e+07
# std      1.720810e+07
# min      1.110000e+02
# 25%      3.190000e+04
# 50%      1.720000e+07
# 75%      2.995000e+07
# max      3.495000e+08
# Name: Precio, dtype: float64

# %% [markdown]
# **Data Split and Normalize**

# %% [markdown]
# ### MODELS

# %% [markdown]
# ### Comparison bewtween models

# %% [markdown]
# ### Final Model
